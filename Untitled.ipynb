# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("dictionary.csv")

# %%
df.head()
# Out:
#   Hebrew-Niqqud Hebrew-Base                                     Link  \
# 0           אָב          אב     https://www.pealim.com/dict/6009-av/
# 1        אַבָּא         אבא    https://www.pealim.com/dict/4845-aba/
# 2           אֵב          אב     https://www.pealim.com/dict/4216-ev/
# 3        אָבִיב        אביב   https://www.pealim.com/dict/4084-aviv/
# 4      אֲבֵידָה       אבידה  https://www.pealim.com/dict/8743-aveda/
#
#   Transliteration       Root                   Part-of-Speech  \
# 0              av          -                 Noun – masculine
# 1             aba          -                             Noun
# 2              ev  א - ב - ב  Noun – ketel pattern, masculine
# 3            aviv  א - ב - ב  Noun – katil pattern, masculine
# 4           aveda  א - ב - ד   Noun – ktela pattern, feminine
#
#                                 English Noun_singularAbsolute  \
# 0                                father                   אָב
# ...

# %%
df[df["Hebrew-Base"]=="לפרוש"][['Hebrew-Niqqud','Hebrew-Base','English']].to_dict('records')[1]
# Out:
# {'Hebrew-Niqqud': 'לִפְרוֹשׂ',
#  'Hebrew-Base': 'לפרוש',
#  'English': 'to spread, to stretch out'}

# %%
df.columns
# Out:
# Index(['Hebrew-Niqqud', 'Hebrew-Base', 'Link', 'Transliteration', 'Root',
#        'Part-of-Speech', 'English', 'Noun_singularAbsolute',
#        'Noun_pluralAbsolute', 'Noun_singularConstruct', 'Noun_pluralConstruct',
#        'Adj_SM', 'Adj_SF', 'Adj_PM', 'Adj_PF', 'Verb_ActivePresentSM',
#        'Verb_ActivePresentSF', 'Verb_ActivePresentPM', 'Verb_ActivePresentPF',
#        'Verb_ActivePastS1', 'Verb_ActivePastP1', 'Verb_ActivePastSM2',
#        'Verb_ActivePastSF2', 'Verb_ActivePastPM2', 'Verb_ActivePastPF2',
#        'Verb_ActivePastSM3', 'Verb_ActivePastSF3', 'Verb_ActivePastPM3',
#        'Verb_ActivePastPF3', 'Verb_ActiveFutureS1', 'Verb_ActiveFutureP1',
#        'Verb_ActiveFutureSM2', 'Verb_ActiveFutureSF2', 'Verb_ActiveFuturePM2',
#        'Verb_ActiveFuturePF2', 'Verb_ActiveFutureSM3', 'Verb_ActiveFutureSF3',
#        'Verb_ActiveFuturePM3', 'Verb_ActiveFuturePF3', 'Verb_ImperativeSM',
#        'Verb_ImperativeSF', 'Verb_ImperativePM', 'Verb_ImperativePF',
# ...

# %%
for c in df.columns:
    print('(item.'+c.strip()+' && item.' + c.strip() + '.replace(/[\\u0591-\\u05C7]/g, "").includes(query.replace(/[\\u0591-\\u05C7]/g, ""))) ||')
# Out:
# (item.Hebrew-Niqqud && item.Hebrew-Niqqud.replace(/[\u0591-\u05C7]/g, "").includes(query.replace(/[\u0591-\u05C7]/g, ""))) ||
# (item.Hebrew-Base && item.Hebrew-Base.replace(/[\u0591-\u05C7]/g, "").includes(query.replace(/[\u0591-\u05C7]/g, ""))) ||
# (item.Link && item.Link.replace(/[\u0591-\u05C7]/g, "").includes(query.replace(/[\u0591-\u05C7]/g, ""))) ||
# (item.Transliteration && item.Transliteration.replace(/[\u0591-\u05C7]/g, "").includes(query.replace(/[\u0591-\u05C7]/g, ""))) ||
# (item.Root && item.Root.replace(/[\u0591-\u05C7]/g, "").includes(query.replace(/[\u0591-\u05C7]/g, ""))) ||
# (item.Part-of-Speech && item.Part-of-Speech.replace(/[\u0591-\u05C7]/g, "").includes(query.replace(/[\u0591-\u05C7]/g, ""))) ||
# (item.English && item.English.replace(/[\u0591-\u05C7]/g, "").includes(query.replace(/[\u0591-\u05C7]/g, ""))) ||
# (item.Noun_singularAbsolute && item.Noun_singularAbsolute.replace(/[\u0591-\u05C7]/g, "").includes(query.replace(/[\u0591-\u05C7]/g, ""))) ||
# ...

# %%
for c in df.columns:
    print("{props."+c.strip()+"}")
# Out:
# {props.Hebrew-Niqqud}
# {props.Hebrew-Base}
# {props.Link}
# {props.Transliteration}
# {props.Root}
# {props.Part-of-Speech}
# {props.English}
# {props.Noun_singularAbsolute}
# {props.Noun_pluralAbsolute}
# {props.Noun_singularConstruct}
# {props.Noun_pluralConstruct}
# {props.Adj_SM}
# {props.Adj_SF}
# {props.Adj_PM}
# {props.Adj_PF}
# {props.Verb_ActivePresentSM}
# {props.Verb_ActivePresentSF}
# {props.Verb_ActivePresentPM}
# {props.Verb_ActivePresentPF}
# {props.Verb_ActivePastS1}
# {props.Verb_ActivePastP1}
# {props.Verb_ActivePastSM2}
# {props.Verb_ActivePastSF2}
# {props.Verb_ActivePastPM2}
# {props.Verb_ActivePastPF2}
# {props.Verb_ActivePastSM3}
# {props.Verb_ActivePastSF3}
# {props.Verb_ActivePastPM3}
# {props.Verb_ActivePastPF3}
# {props.Verb_ActiveFutureS1}
# {props.Verb_ActiveFutureP1}
# {props.Verb_ActiveFutureSM2}
# {props.Verb_ActiveFutureSF2}
# {props.Verb_ActiveFuturePM2}
# {props.Verb_ActiveFuturePF2}
# {props.Verb_ActiveFutureSM3}
# {props.Verb_ActiveFutureSF3}
# ...
